# %% [markdown]
# # 課題1: 自己紹介プログラム
#
# 名前と年齢を変数に格納し、自己紹介を出力するプログラムです。

# %%
# 名前と年齢を変数に代入
name = "山田太郎"
age = 25

# 自己紹介を出力
print(f"はじめまして、 {name} と申します。")
print(f"年齢は {age} 歳です。来年は {age + 1} 歳になります。")
print("よろしくお願いします。")
